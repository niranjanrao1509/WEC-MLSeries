# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('train.csv')

# %%
fare = dataset.sort_values(by='Fare',axis=0, ascending=False)
fare
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 737          738         1       1
# 679          680         1       1
# 88            89         1       1
# 27            28         0       1
# 341          342         1       1
# 438          439         0       1
# 311          312         1       1
# 742          743         1       1
# 118          119         0       1
# 299          300         1       1
# 557          558         0       1
# 700          701         1       1
# 380          381         1       1
# 716          717         1       1
# 527          528         0       1
# 377          378         0       1
# 730          731         1       1
# 779          780         1       1
# 689          690         1       1
# 318          319         1       1
# 856          857         1       1
# 268          269         1       1
# 332          333         0       1
# 609          610         1       1
# ...

# %%
fare.to_csv("2.csv", index=False)
